# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams['figure.dpi'] = 300

# %%
import pandas as pd  
import joblib  
import shap  
import numpy as np  
import matplotlib.pyplot as plt  
from pixelmed_calc.medical_imaging.RadiologyComponents.shapvalue import analyze_model_with_shap

# Example usage:  
analyze_model_with_shap('D:\\pixelmedAI\\function_pm\\note1—影像组学\\二分类指定数据集\\results\\pred\\x_train.csv',  
                         'D:\\pixelmedAI\\function_pm\\note1—影像组学\\二分类指定数据集\\results\\pred\\y_train.csv',  
                         'D:\\pixelmedAI\\function_pm\\note1—影像组学\\二分类指定数据集\\results\\model_weight\\rbf_SVM.pkl',save_dir='results')
# Out:
# ...
#   0%|          | 0/712 [00:00<?, ?it/s]
# shap_values: (2, 712, 29)
#   0%|          | 0/712 [00:00<?, ?it/s]
# shap_values2: (712, 29, 2)
