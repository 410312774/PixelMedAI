# %% [markdown]
# def plot_confusion_matrix(y_test_input, xdata_input=None, model_input=None, y_pred_input=None, figsize=(10, 7), annot_size=15, cmap='Reds',title='Confusion Matrix'):
#     """
#     Plots the confusion matrix from the provided inputs.
#
#     Parameters:
#     - y_test_input (str or pd.Series): Path to the CSV file containing true labels, or directly a Series of labels.
#     - xdata_input (str or pd.DataFrame, optional): Path to the CSV file containing feature data, or directly a DataFrame.
#     - model_input (str or model object, optional): Path to the saved model file, or directly a loaded model.
#     - y_pred_input (pd.Series or numpy array, optional): Directly provide predicted labels.
#     - figsize (tuple): Size of the figure (default is (10, 7)).
#     - annot_size (int): Size of the annotation text in the heatmap (default is 15).
#     - cmap (str): Colormap for the heatmap (default is 'Reds').
#     """
# ``` python
# # Example usage with direct predictions:
# # y_test_series = pd.Series([...])  # Your actual labels
# # y_pred_series = pd.Series([...])  # Your predicted labels
# # plot_confusion_matrix(y_test_series, y_pred_input=y_pred_series)
# # y_test=pd.read_csv(r"D:\pixelmedAI\function_pm\note1—影像组学\多分类指定数据集\results\pred\y_train.csv")['label']
# # model= joblib.load(filename=r"D:\pixelmedAI\function_pm\note1—影像组学\多分类指定数据集\results\model_weight\sigmoid_SVM.pkl")
# # xdata=pd.read_csv(r"D:\pixelmedAI\function_pm\note1—影像组学\多分类指定数据集\results\pred\x_train.csv")
# # # Example usage with file paths and model provided:
# # plot_confusion_matrix(r"D:\pixelmedAI\function_pm\note1—影像组学\多分类指定数据集\results\pred\y_train.csv", r"D:\pixelmedAI\function_pm\note1—影像组学\多分类指定数据集\results\pred\x_train.csv",r"D:\pixelmedAI\function_pm\note1—影像组学\多分类指定数据集\results\model_weight\sigmoid_SVM.pkl")
# # plt.savefig('confusion.svg')

# %%
from pixelmed_calc.medical_imaging.Ploting.plot_metric import plot_confusion_matrix
from sklearn.metrics import confusion_matrix  
import seaborn as sns  
import matplotlib.pyplot as plt  
import pandas as pd  
import joblib  


# Example usage with direct predictions:  
# y_test_series = pd.Series([...])  # Your actual labels  
# y_pred_series = pd.Series([...])  # Your predicted labels  
# plot_confusion_matrix(y_test_series, y_pred_input=y_pred_series)  

# Example usage with file paths and model provided:  
plot_confusion_matrix(r"D:\pixelmedAI\function_pm\note1—影像组学\多分类指定数据集\results\pred\y_train.csv",
 r"D:\pixelmedAI\function_pm\note1—影像组学\多分类指定数据集\results\pred\x_train.csv",
 r"D:\pixelmedAI\function_pm\note1—影像组学\多分类指定数据集\results\model_weight\sigmoid_SVM.pkl")
plt.savefig('confusion.svg')

# %%
import pandas as pd
ydata=pd.read_csv(r"D:\pixelmedAI\function_pm\note2-深度学习分类\results\train_metrics_epoch_37.csv")
y_test_input=ydata['target']
y_pred_input=ydata['prediction']
plot_confusion_matrix(y_test_input=y_test_input,
 y_pred_input=y_pred_input)
plt.savefig('confusion1.svg')
