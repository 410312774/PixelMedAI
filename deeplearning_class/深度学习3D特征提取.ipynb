# %% [markdown]
# ## 深度学习特征
#
# 提取CT、MRI、内镜、Xray等影像数据的深度学习特征。
#
#
# 1. 将待提取的数据转化成nii(nii.gz)。
# 2. 获取到指定目录的所有图像数据。
# 3. 选择要提取什么样的模型的深度学习特征，目前支持ResNet3d深度学习模型。（可以考虑迁移学习）
#   > 只支持ResNet3d，是因为目前仅有resnet存在预训练的模型。
# 4. 提取特征，保存特征文件。

# %% [markdown]
# ### 获取待提取特征的NII数据
#
# 提供两种批量处理的模式：
# 1. 目录模式，提取指定目录下的所有jpg文件的特征。
# 2. 文件模式，待提取的数据存储在文件中，每行一个样本。
#
# 当然也可以在最后自己指定手动提取指定若干文件。

# %%
import os

# 目录模式
mydir = r'C:\Users\yxzdxzj\Desktop\function\pm_data\MR\images'
directory = os.path.expanduser(mydir)
test_samples = [os.path.join(directory, p) 
                for p in os.listdir(directory) if p.endswith('.nii') or p.endswith('.nii.gz')]

# 文件模式
# test_file = ''
# with open(test_file) as f:
#     test_samples = [l.strip() for l in f.readlines()]

# 自定义模式
# test_sampleses = ['path2jpg']
test_samples
# Out:
# ['C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\0.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\1.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\10.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\100.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\101.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\102.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\103.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\104.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\105.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\106.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\107.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\108.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\109.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\11.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\110.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\111.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\112.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\113.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\114.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\115.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\116.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\117.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\118.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\119.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\12.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\120.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\121.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\122.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\123.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\124.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\125.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\126.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\127.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\128.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\129.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\13.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\130.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\131.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\132.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\133.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\134.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\135.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\136.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\137.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\138.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\139.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\14.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\140.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\141.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\142.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\143.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\144.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\145.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\146.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\147.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\148.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\149.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\15.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\150.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\151.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\152.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\153.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\154.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\155.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\156.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\157.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\158.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\159.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\16.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\160.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\161.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\162.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\163.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\164.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\165.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\166.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\167.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\168.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\169.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\17.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\170.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\171.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\172.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\173.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\174.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\175.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\176.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\177.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\178.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\179.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\18.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\180.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\181.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\182.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\183.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\184.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\185.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\186.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\187.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\188.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\189.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\19.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\190.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\191.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\192.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\193.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\194.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\195.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\196.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\197.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\198.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\199.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\2.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\20.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\200.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\201.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\202.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\203.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\204.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\205.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\206.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\207.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\208.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\209.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\21.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\210.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\211.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\212.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\213.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\214.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\215.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\216.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\217.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\218.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\219.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\22.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\220.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\221.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\222.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\223.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\224.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\225.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\226.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\227.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\228.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\229.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\23.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\230.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\231.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\232.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\233.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\234.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\235.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\236.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\24.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\25.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\26.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\27.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\28.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\29.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\3.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\30.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\31.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\32.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\33.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\34.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\35.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\36.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\37.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\38.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\39.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\4.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\40.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\41.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\42.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\43.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\44.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\45.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\46.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\47.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\48.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\49.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\5.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\50.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\51.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\52.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\53.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\54.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\55.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\56.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\57.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\58.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\59.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\6.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\60.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\61.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\62.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\63.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\64.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\65.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\66.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\67.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\68.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\69.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\7.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\70.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\71.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\72.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\73.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\74.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\75.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\76.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\77.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\78.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\79.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\8.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\80.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\81.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\82.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\83.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\84.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\85.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\86.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\87.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\88.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\89.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\9.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\90.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\91.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\92.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\93.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\94.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\95.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\96.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\97.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\98.nii.gz',
#  'C:\\Users\\yxzdxzj\\Desktop\\function\\pm_data\\MR\\images\\99.nii.gz']

# %% [markdown]
# ## 确定提取特征
#
# 通过关键词获取要提取那一层的特征。
#
# ### 支持的模型名称
#
# 模型名称替换代码中的 `model_name`变量的值。
#
# | **模型系列** | **模型名称**                                                 |
# | ------------ | ------------------------------------------------------------ |
# | ResNet       | resnet10, resnet18, resnet34, resnet50, resnet101, resnet152, resnet200 |

# %%
from pixelmed_core.core import create_model
from pixelmed_calc.custom.components.comp2 import extract3d, init_from_model3d
'''
案例resnet34是3D模型，案例resnet50是2D模型
'''

model_name = 'resnet34'
model_path = r'C:\Users\yxzdxzj\Desktop\function\note2-深度学习分类\resnet34\20230904\viz\BEST-training-params.pth'
#如果使用自带模型请将pretrained=True,并将num_classes=2删除
model, transformer, device = init_from_model3d(model_name=f'classification3d.{model_name}', pretrained=model_path, in_channels=1,num_classes=2)
for n, m in model.named_modules():
    print('Feature name:', n, "|| Module:", m)
# Out:
# 成功加载C:\Users\yxzdxzj\Desktop\function\note2-深度学习分类\resnet34\20230904\viz\BEST-training-params.pth模型参数。
# 成功加载C:\Users\yxzdxzj\Desktop\function\note2-深度学习分类\resnet34\20230904\viz\BEST-training-params.pth模型参数。
# Feature name:  || Module: ResNet(
#   (conv1): Conv3d(1, 64, kernel_size=(7, 7, 7), stride=(1, 2, 2), padding=(3, 3, 3), bias=False)
#   (bn1): BatchNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool3d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): ResNetBlock(
#       (conv1): Conv3d(64, 64, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#       (bn1): BatchNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv3d(64, 64, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#       (bn2): BatchNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): ResNetBlock(
#       (conv1): Conv3d(64, 64, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#       (bn1): BatchNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv3d(64, 64, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#       (bn2): BatchNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (2): ResNetBlock(
#       (conv1): Conv3d(64, 64, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#       (bn1): BatchNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv3d(64, 64, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#       (bn2): BatchNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): ResNetBlock(
#       (conv1): Conv3d(64, 128, kernel_size=(3, 3, 3), stride=(2, 2, 2), padding=(1, 1, 1), bias=False)
#       (bn1): BatchNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv3d(128, 128, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#       (bn2): BatchNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): ResNetBlock(
#       (conv1): Conv3d(128, 128, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#       (bn1): BatchNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv3d(128, 128, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#       (bn2): BatchNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (2): ResNetBlock(
#       (conv1): Conv3d(128, 128, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#       (bn1): BatchNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv3d(128, 128, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#       (bn2): BatchNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (3): ResNetBlock(
#       (conv1): Conv3d(128, 128, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#       (bn1): BatchNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv3d(128, 128, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#       (bn2): BatchNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): ResNetBlock(
#       (conv1): Conv3d(128, 256, kernel_size=(3, 3, 3), stride=(2, 2, 2), padding=(1, 1, 1), bias=False)
#       (bn1): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv3d(256, 256, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#       (bn2): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): ResNetBlock(
#       (conv1): Conv3d(256, 256, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#       (bn1): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv3d(256, 256, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#       (bn2): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (2): ResNetBlock(
#       (conv1): Conv3d(256, 256, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#       (bn1): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv3d(256, 256, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#       (bn2): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (3): ResNetBlock(
#       (conv1): Conv3d(256, 256, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#       (bn1): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv3d(256, 256, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#       (bn2): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (4): ResNetBlock(
#       (conv1): Conv3d(256, 256, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#       (bn1): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv3d(256, 256, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#       (bn2): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (5): ResNetBlock(
#       (conv1): Conv3d(256, 256, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#       (bn1): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv3d(256, 256, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#       (bn2): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): ResNetBlock(
#       (conv1): Conv3d(256, 512, kernel_size=(3, 3, 3), stride=(2, 2, 2), padding=(1, 1, 1), bias=False)
#       (bn1): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv3d(512, 512, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#       (bn2): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): ResNetBlock(
#       (conv1): Conv3d(512, 512, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#       (bn1): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv3d(512, 512, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#       (bn2): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (2): ResNetBlock(
#       (conv1): Conv3d(512, 512, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#       (bn1): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv3d(512, 512, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#       (bn2): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool3d(output_size=(1, 1, 1))
#   (fc): Linear(in_features=512, out_features=2, bias=True)
# )
# Feature name: conv1 || Module: Conv3d(1, 64, kernel_size=(7, 7, 7), stride=(1, 2, 2), padding=(3, 3, 3), bias=False)
# Feature name: bn1 || Module: BatchNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Feature name: relu || Module: ReLU(inplace=True)
# Feature name: maxpool || Module: MaxPool3d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
# Feature name: layer1 || Module: Sequential(
#   (0): ResNetBlock(
#     (conv1): Conv3d(64, 64, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#     (bn1): BatchNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#     (conv2): Conv3d(64, 64, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#     (bn2): BatchNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (1): ResNetBlock(
#     (conv1): Conv3d(64, 64, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#     (bn1): BatchNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#     (conv2): Conv3d(64, 64, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#     (bn2): BatchNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (2): ResNetBlock(
#     (conv1): Conv3d(64, 64, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#     (bn1): BatchNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#     (conv2): Conv3d(64, 64, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#     (bn2): BatchNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
# )
# Feature name: layer1.0 || Module: ResNetBlock(
#   (conv1): Conv3d(64, 64, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#   (bn1): BatchNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (conv2): Conv3d(64, 64, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#   (bn2): BatchNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# )
# Feature name: layer1.0.conv1 || Module: Conv3d(64, 64, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
# Feature name: layer1.0.bn1 || Module: BatchNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Feature name: layer1.0.relu || Module: ReLU(inplace=True)
# Feature name: layer1.0.conv2 || Module: Conv3d(64, 64, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
# Feature name: layer1.0.bn2 || Module: BatchNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Feature name: layer1.1 || Module: ResNetBlock(
#   (conv1): Conv3d(64, 64, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#   (bn1): BatchNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (conv2): Conv3d(64, 64, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#   (bn2): BatchNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# )
# Feature name: layer1.1.conv1 || Module: Conv3d(64, 64, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
# Feature name: layer1.1.bn1 || Module: BatchNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Feature name: layer1.1.relu || Module: ReLU(inplace=True)
# Feature name: layer1.1.conv2 || Module: Conv3d(64, 64, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
# Feature name: layer1.1.bn2 || Module: BatchNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Feature name: layer1.2 || Module: ResNetBlock(
#   (conv1): Conv3d(64, 64, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#   (bn1): BatchNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (conv2): Conv3d(64, 64, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#   (bn2): BatchNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# )
# Feature name: layer1.2.conv1 || Module: Conv3d(64, 64, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
# Feature name: layer1.2.bn1 || Module: BatchNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Feature name: layer1.2.relu || Module: ReLU(inplace=True)
# Feature name: layer1.2.conv2 || Module: Conv3d(64, 64, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
# Feature name: layer1.2.bn2 || Module: BatchNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Feature name: layer2 || Module: Sequential(
#   (0): ResNetBlock(
#     (conv1): Conv3d(64, 128, kernel_size=(3, 3, 3), stride=(2, 2, 2), padding=(1, 1, 1), bias=False)
#     (bn1): BatchNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#     (conv2): Conv3d(128, 128, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#     (bn2): BatchNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (1): ResNetBlock(
#     (conv1): Conv3d(128, 128, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#     (bn1): BatchNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#     (conv2): Conv3d(128, 128, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#     (bn2): BatchNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (2): ResNetBlock(
#     (conv1): Conv3d(128, 128, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#     (bn1): BatchNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#     (conv2): Conv3d(128, 128, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#     (bn2): BatchNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (3): ResNetBlock(
#     (conv1): Conv3d(128, 128, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#     (bn1): BatchNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#     (conv2): Conv3d(128, 128, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#     (bn2): BatchNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
# )
# Feature name: layer2.0 || Module: ResNetBlock(
#   (conv1): Conv3d(64, 128, kernel_size=(3, 3, 3), stride=(2, 2, 2), padding=(1, 1, 1), bias=False)
#   (bn1): BatchNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (conv2): Conv3d(128, 128, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#   (bn2): BatchNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# )
# Feature name: layer2.0.conv1 || Module: Conv3d(64, 128, kernel_size=(3, 3, 3), stride=(2, 2, 2), padding=(1, 1, 1), bias=False)
# Feature name: layer2.0.bn1 || Module: BatchNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Feature name: layer2.0.relu || Module: ReLU(inplace=True)
# Feature name: layer2.0.conv2 || Module: Conv3d(128, 128, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
# Feature name: layer2.0.bn2 || Module: BatchNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Feature name: layer2.1 || Module: ResNetBlock(
#   (conv1): Conv3d(128, 128, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#   (bn1): BatchNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (conv2): Conv3d(128, 128, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#   (bn2): BatchNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# )
# Feature name: layer2.1.conv1 || Module: Conv3d(128, 128, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
# Feature name: layer2.1.bn1 || Module: BatchNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Feature name: layer2.1.relu || Module: ReLU(inplace=True)
# Feature name: layer2.1.conv2 || Module: Conv3d(128, 128, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
# Feature name: layer2.1.bn2 || Module: BatchNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Feature name: layer2.2 || Module: ResNetBlock(
#   (conv1): Conv3d(128, 128, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#   (bn1): BatchNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (conv2): Conv3d(128, 128, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#   (bn2): BatchNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# )
# Feature name: layer2.2.conv1 || Module: Conv3d(128, 128, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
# Feature name: layer2.2.bn1 || Module: BatchNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Feature name: layer2.2.relu || Module: ReLU(inplace=True)
# Feature name: layer2.2.conv2 || Module: Conv3d(128, 128, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
# Feature name: layer2.2.bn2 || Module: BatchNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Feature name: layer2.3 || Module: ResNetBlock(
#   (conv1): Conv3d(128, 128, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#   (bn1): BatchNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (conv2): Conv3d(128, 128, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#   (bn2): BatchNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# )
# Feature name: layer2.3.conv1 || Module: Conv3d(128, 128, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
# Feature name: layer2.3.bn1 || Module: BatchNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Feature name: layer2.3.relu || Module: ReLU(inplace=True)
# Feature name: layer2.3.conv2 || Module: Conv3d(128, 128, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
# Feature name: layer2.3.bn2 || Module: BatchNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Feature name: layer3 || Module: Sequential(
#   (0): ResNetBlock(
#     (conv1): Conv3d(128, 256, kernel_size=(3, 3, 3), stride=(2, 2, 2), padding=(1, 1, 1), bias=False)
#     (bn1): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#     (conv2): Conv3d(256, 256, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#     (bn2): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (1): ResNetBlock(
#     (conv1): Conv3d(256, 256, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#     (bn1): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#     (conv2): Conv3d(256, 256, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#     (bn2): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (2): ResNetBlock(
#     (conv1): Conv3d(256, 256, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#     (bn1): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#     (conv2): Conv3d(256, 256, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#     (bn2): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (3): ResNetBlock(
#     (conv1): Conv3d(256, 256, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#     (bn1): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#     (conv2): Conv3d(256, 256, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#     (bn2): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (4): ResNetBlock(
#     (conv1): Conv3d(256, 256, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#     (bn1): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#     (conv2): Conv3d(256, 256, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#     (bn2): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (5): ResNetBlock(
#     (conv1): Conv3d(256, 256, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#     (bn1): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#     (conv2): Conv3d(256, 256, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#     (bn2): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
# )
# Feature name: layer3.0 || Module: ResNetBlock(
#   (conv1): Conv3d(128, 256, kernel_size=(3, 3, 3), stride=(2, 2, 2), padding=(1, 1, 1), bias=False)
#   (bn1): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (conv2): Conv3d(256, 256, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#   (bn2): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# )
# Feature name: layer3.0.conv1 || Module: Conv3d(128, 256, kernel_size=(3, 3, 3), stride=(2, 2, 2), padding=(1, 1, 1), bias=False)
# Feature name: layer3.0.bn1 || Module: BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Feature name: layer3.0.relu || Module: ReLU(inplace=True)
# Feature name: layer3.0.conv2 || Module: Conv3d(256, 256, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
# Feature name: layer3.0.bn2 || Module: BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Feature name: layer3.1 || Module: ResNetBlock(
#   (conv1): Conv3d(256, 256, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#   (bn1): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (conv2): Conv3d(256, 256, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#   (bn2): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# )
# Feature name: layer3.1.conv1 || Module: Conv3d(256, 256, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
# Feature name: layer3.1.bn1 || Module: BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Feature name: layer3.1.relu || Module: ReLU(inplace=True)
# Feature name: layer3.1.conv2 || Module: Conv3d(256, 256, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
# Feature name: layer3.1.bn2 || Module: BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Feature name: layer3.2 || Module: ResNetBlock(
#   (conv1): Conv3d(256, 256, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#   (bn1): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (conv2): Conv3d(256, 256, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#   (bn2): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# )
# Feature name: layer3.2.conv1 || Module: Conv3d(256, 256, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
# Feature name: layer3.2.bn1 || Module: BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Feature name: layer3.2.relu || Module: ReLU(inplace=True)
# Feature name: layer3.2.conv2 || Module: Conv3d(256, 256, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
# Feature name: layer3.2.bn2 || Module: BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Feature name: layer3.3 || Module: ResNetBlock(
#   (conv1): Conv3d(256, 256, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#   (bn1): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (conv2): Conv3d(256, 256, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#   (bn2): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# )
# Feature name: layer3.3.conv1 || Module: Conv3d(256, 256, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
# Feature name: layer3.3.bn1 || Module: BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Feature name: layer3.3.relu || Module: ReLU(inplace=True)
# Feature name: layer3.3.conv2 || Module: Conv3d(256, 256, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
# Feature name: layer3.3.bn2 || Module: BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Feature name: layer3.4 || Module: ResNetBlock(
#   (conv1): Conv3d(256, 256, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#   (bn1): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (conv2): Conv3d(256, 256, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#   (bn2): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# )
# Feature name: layer3.4.conv1 || Module: Conv3d(256, 256, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
# Feature name: layer3.4.bn1 || Module: BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Feature name: layer3.4.relu || Module: ReLU(inplace=True)
# Feature name: layer3.4.conv2 || Module: Conv3d(256, 256, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
# Feature name: layer3.4.bn2 || Module: BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Feature name: layer3.5 || Module: ResNetBlock(
#   (conv1): Conv3d(256, 256, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#   (bn1): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (conv2): Conv3d(256, 256, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#   (bn2): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# )
# Feature name: layer3.5.conv1 || Module: Conv3d(256, 256, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
# Feature name: layer3.5.bn1 || Module: BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Feature name: layer3.5.relu || Module: ReLU(inplace=True)
# Feature name: layer3.5.conv2 || Module: Conv3d(256, 256, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
# Feature name: layer3.5.bn2 || Module: BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Feature name: layer4 || Module: Sequential(
#   (0): ResNetBlock(
#     (conv1): Conv3d(256, 512, kernel_size=(3, 3, 3), stride=(2, 2, 2), padding=(1, 1, 1), bias=False)
#     (bn1): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#     (conv2): Conv3d(512, 512, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#     (bn2): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (1): ResNetBlock(
#     (conv1): Conv3d(512, 512, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#     (bn1): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#     (conv2): Conv3d(512, 512, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#     (bn2): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (2): ResNetBlock(
#     (conv1): Conv3d(512, 512, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#     (bn1): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#     (conv2): Conv3d(512, 512, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#     (bn2): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
# )
# Feature name: layer4.0 || Module: ResNetBlock(
#   (conv1): Conv3d(256, 512, kernel_size=(3, 3, 3), stride=(2, 2, 2), padding=(1, 1, 1), bias=False)
#   (bn1): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (conv2): Conv3d(512, 512, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#   (bn2): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# )
# Feature name: layer4.0.conv1 || Module: Conv3d(256, 512, kernel_size=(3, 3, 3), stride=(2, 2, 2), padding=(1, 1, 1), bias=False)
# Feature name: layer4.0.bn1 || Module: BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Feature name: layer4.0.relu || Module: ReLU(inplace=True)
# Feature name: layer4.0.conv2 || Module: Conv3d(512, 512, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
# Feature name: layer4.0.bn2 || Module: BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Feature name: layer4.1 || Module: ResNetBlock(
#   (conv1): Conv3d(512, 512, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#   (bn1): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (conv2): Conv3d(512, 512, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#   (bn2): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# )
# Feature name: layer4.1.conv1 || Module: Conv3d(512, 512, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
# Feature name: layer4.1.bn1 || Module: BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Feature name: layer4.1.relu || Module: ReLU(inplace=True)
# Feature name: layer4.1.conv2 || Module: Conv3d(512, 512, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
# Feature name: layer4.1.bn2 || Module: BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Feature name: layer4.2 || Module: ResNetBlock(
#   (conv1): Conv3d(512, 512, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#   (bn1): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (conv2): Conv3d(512, 512, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#   (bn2): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# )
# Feature name: layer4.2.conv1 || Module: Conv3d(512, 512, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
# Feature name: layer4.2.bn1 || Module: BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Feature name: layer4.2.relu || Module: ReLU(inplace=True)
# Feature name: layer4.2.conv2 || Module: Conv3d(512, 512, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
# Feature name: layer4.2.bn2 || Module: BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Feature name: avgpool || Module: AdaptiveAvgPool3d(output_size=(1, 1, 1))
# Feature name: fc || Module: Linear(in_features=512, out_features=2, bias=True)

# %% [markdown]
# ## 提取特征
#
# `Feature name:` 之后的名称为要提取的特征名，例如`layer3.0.conv2`, 一般深度学习特征提取最后一层，例如`avgpool`

# %%
import torch
from functools import partial
from pixelmed_calc.custom.components.comp2 import extract3d, print_feature_hook, reg_hook_on_module
from monai.data import ImageDataset
from torch.utils.data import DataLoader

feature_name = 'avgpool'
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
with open('feature.txt', 'w') as outfile:
    hook = partial(print_feature_hook, fp=outfile)
    find_num = reg_hook_on_module(feature_name, model, hook)
    val_ds = ImageDataset(image_files=test_samples, transform=transformer)
    # create a validation data loader
    val_loader = DataLoader(val_ds, batch_size=1, num_workers=0)
    
    results = extract3d(val_loader, test_samples, model, device, fp=outfile)

# %% [markdown]
# ### 读取数据

# %%
import pandas as pd
features = pd.read_csv('feature.txt', sep=',', header=None)
features.columns=['ID'] + list(features.columns[1:])
features.head()
# Out:
#            ID        1        2      3        4        5    6        7  \
# 0    0.nii.gz  188.052  186.968  0.103  148.222  150.240  0.0  144.502
# 1    1.nii.gz  180.632  179.124  0.105  142.204  144.070  0.0  138.391
# 2   10.nii.gz  203.683  202.729  0.076  160.594  163.115  0.0  156.954
# 3  100.nii.gz  197.808  196.622  0.111  155.791  158.144  0.0  152.068
# 4  101.nii.gz  208.255  207.715  0.068  164.329  166.892  0.0  160.763
#
#         8        9  ...     503  504      505  506      507  508      509  \
# 0  10.599  184.591  ...   9.039  0.0  140.444  0.0  130.847  0.0  107.976
# 1  10.340  177.645  ...   8.725  0.0  134.624  0.0  125.661  0.0  103.555
# 2  11.161  199.519  ...   9.872  0.0  152.601  0.0  142.344  0.0  117.426
# 3  10.964  193.848  ...   9.535  0.0  147.863  0.0  137.940  0.0  113.704
# 4  11.332  203.835  ...  10.034  0.0  156.108  0.0  145.380  0.0  120.193
#
#        510     511      512
# 0  123.329  63.021   91.879
# 1  118.138  60.476   88.167
# 2  133.885  68.625   99.974
# 3  129.701  66.444   96.836
# 4  137.179  70.168  102.188
#
# [5 rows x 513 columns]

# %% [markdown]
# ### 深度特征压缩
#
# 深度学习特征压缩，注意压缩到的维度需要小于样本数
#
# ```python
# def compress_df_feature(features: pd.DataFrame, dim: int, not_compress: Union[str, List[str]] = None,
#                         prefix='') -> pd.DataFrame:
#     """
#     压缩深度学习特征
#     Args:
#         features: 特征DataFrame
#         dim: 需要压缩到的维度，此值需要小于样本数
#         not_compress: 不进行压缩的列。
#         prefix: 所有特征的前缀。
#
#     Returns:
#
#     """
# ```

# %%
from pixelmed_calc.custom.components.comp1 import compress_df_feature

cm_features = compress_df_feature(features=features, dim=32, prefix='DL_', not_compress='ID')
cm_features.to_csv('compress_features.csv', header=True, index=False)
