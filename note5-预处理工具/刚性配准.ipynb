# %%
from pixelmed_calc.medical_imaging.RadiologyComponents.tools.registration import register_images_in_folders
# 主程序
fixed_folder = r"D:\pixelmedAI\function_pm\pm_data\MR\ICC\ICC1\images"
moving_folder = r"D:\pixelmedAI\function_pm\pm_data\MR\ICC\ICC2\images"
output_folder = 'results'

register_images_in_folders(fixed_folder, moving_folder, output_folder)
# Out:
# Registering 1.nii.gz...
# Optimizer stop condition: RegularStepGradientDescentOptimizerv4: Step too small after 19 iterations. Current step (6.10352e-05) is less than minimum step (0.0001).
# Final metric value: -1.2980589744419104
# Finished registering 1.nii.gz.
# Registering 10.nii.gz...
# Optimizer stop condition: RegularStepGradientDescentOptimizerv4: Step too small after 35 iterations. Current step (6.10352e-05) is less than minimum step (0.0001).
# Final metric value: -1.099744270109819
# Finished registering 10.nii.gz.
# Registering 11.nii.gz...
# Optimizer stop condition: RegularStepGradientDescentOptimizerv4: Step too small after 176 iterations. Current step (6.10352e-05) is less than minimum step (0.0001).
# Final metric value: -0.9140807094317592
# Finished registering 11.nii.gz.
# Registering 12.nii.gz...
# Optimizer stop condition: RegularStepGradientDescentOptimizerv4: Step too small after 24 iterations. Current step (6.10352e-05) is less than minimum step (0.0001).
# ...
